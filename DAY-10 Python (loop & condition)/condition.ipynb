# %% [markdown]
# # IF statement

# %%
age = 20

if age >= 18:
    print("Adult")
# Out:
# Adult

# %% [markdown]
# # If-else statement

# %%
age = 15

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %% [markdown]
# # If-elif-else statement

# %%
marks = 85

if marks >= 90:
    print("A Grade")
elif marks >= 75:
    print("B Grade")
elif marks >= 50:
    print("C Grade")
else:
    print("Fail")
# Out:
# B Grade

# %% [markdown]
# # Nested IF

# %%
age = 25
has_id = True

if age >= 18:
    if has_id:
        print("Allowed")
# Out:
# Allowed

# %% [markdown]
# # Short form of if-else

# %%
age = 20

status = "Adult" if age >= 18 else "Minor"
print(status)
# Out:
# Adult
